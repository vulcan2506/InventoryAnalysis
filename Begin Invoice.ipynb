# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("BegInvFINAL12312016.csv")

# %%
df = df[:10000]

# %%
df.shape
# Out:
# (10000, 9)

# %%
df.tail()
# Out:
#         InventoryId  Store    City  Brand               Description   Size  \
# 9995  5_SUTTON_5815      5  SUTTON   5815     Godiva Dark Chocolate  750mL
# 9996  5_SUTTON_5826      5  SUTTON   5826       DeKuyper Razzmatazz  750mL
# 9997  5_SUTTON_5828      5  SUTTON   5828         Ryans Irish Cream  750mL
# 9998  5_SUTTON_5847      5  SUTTON   5847  Godiva Chocolate Liqueur  750mL
# 9999  5_SUTTON_5849      5  SUTTON   5849    GranGala Triple Orange  750mL
#
#       onHand  Price   startDate
# 9995       6  21.99  2016-01-01
# 9996      13   8.99  2016-01-01
# 9997       9   8.99  2016-01-01
# 9998       7  21.99  2016-01-01
# 9999      13  16.99  2016-01-01

# %%
 df["Total cost"] = np.multiply(df["onHand"],df["Price"])

# %%
df
# Out:
#             InventoryId  Store          City  Brand  \
# 0     1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1     1_HARDERSFIELD_60      1  HARDERSFIELD     60
# 2     1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 3     1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 4     1_HARDERSFIELD_72      1  HARDERSFIELD     72
# ...                 ...    ...           ...    ...
# 9995      5_SUTTON_5815      5        SUTTON   5815
# 9996      5_SUTTON_5826      5        SUTTON   5826
# 9997      5_SUTTON_5828      5        SUTTON   5828
# 9998      5_SUTTON_5847      5        SUTTON   5847
# 9999      5_SUTTON_5849      5        SUTTON   5849
#
#                       Description   Size  onHand  Price   startDate  \
# 0     Gekkeikan Black & Gold Sake  750mL       8  12.99  2016-01-01
# 1          Canadian Club 1858 VAP  750mL       7  10.99  2016-01-01
# 2        Herradura Silver Tequila  750mL       6  36.99  2016-01-01
# ...

# %%
df["onHand"].unique()
# Out:
# array([  8,   7,   6,   3,  18,   2,   5,  11,  17,   0,  12,  24,   1,
#         13,  14,  29,   4,  28,  10,  25,  57,  27,  48,  16,  36,  15,
#         33,   9,  21,  31,  42,  59,  53,  38,  55,  23,  32,  98,  52,
#         19,  34,  44,  51,  49, 135,  85,  46,  26,  60,  56,  22,  92,
#         20,  66,  39, 147,  35,  30,  64,  54, 123,  79, 104,  75,  73,
#         61, 171, 129, 106, 190, 120, 139,  40,  76,  67,  88,  58,  47,
#        229,  90,  82,  93, 122, 100,  43,  71, 138,  63,  97, 152,  77,
#        121, 206, 105, 124,  45,  37,  50,  68, 240, 108, 109, 107,  65,
#        118,  87, 101, 216,  41, 143,  94,  95,  78,  72,  70,  62, 284,
#         81, 201, 132,  74, 203,  84, 112,  83,  69, 130, 346, 170, 114,
#         89, 156, 262, 277, 180, 163, 228, 296, 116, 115, 185, 320, 183,
#         96, 144, 126, 215, 158, 167, 220, 166,  80, 134, 184, 140, 192,
#         91, 133, 165,  99, 155, 233, 148, 149, 151, 207, 172, 131, 110,
# ...

# %%
df = df.sort_values("onHand",ascending=True)

# %%
df.skew()
# Out:
# /tmp/ipykernel_29486/1665899112.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# Store          0.343319
# Brand          1.304821
# onHand         4.902931
# Price         45.069636
# Total cost     8.665222
# dtype: float64

# %%
plt.boxplot(df["Price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8a91816d90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f8a916282d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f8a93078810>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8a91629290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8a91629b90>],
#  'means': []}

# %%
df.describe()
# Out:
#              Store        Brand        onHand         Price    Total cost
# count  10000.00000  10000.00000  10000.000000  10000.000000  10000.000000
# mean       2.50800  12105.13390     17.728300     21.125084    272.169187
# std        1.37758  12388.51967     25.355768     40.207300    436.209982
# min        1.00000     58.00000      0.000000      0.990000      0.000000
# 25%        1.00000   3485.00000      6.000000      9.990000     89.940000
# 50%        2.00000   5952.00000     11.000000     14.990000    164.890000
# 75%        4.00000  18370.50000     19.000000     22.990000    299.700000
# max        5.00000  47090.00000    416.000000   2999.990000  11999.960000

# %%
plt.figure(figsize=(10,25))
plt.barh(df["Description"],df["onHand"])
# Out:
# <BarContainer object of 10000 artists>

# %%
df1 = df.loc[df["onHand"]>100]
df1.shape
# Out:
# (203, 10)

# %%
plt.figure(figsize=(10,45))
plt.barh(df1["Description"],df1["onHand"])
# Out:
# <BarContainer object of 203 artists>

# %%
plt.barh(df["City"],df["onHand"])
# Out:
# <BarContainer object of 10000 artists>

# %%
df_1 = df.loc[df["City"]=="ASHBORNE"]
df_2 = df.loc[df["City"]=="EANVERNESS"]

# %%
df_1.shape
# Out:
# (2689, 10)

# %%
df_2.shape
# Out:
# (2871, 10)

# %% [markdown]
# ## Analysis On Alcohol Purchased from Ashborne Where quantity was greater than 100

# %%
df_1 = df_1.loc[df_1["onHand"]>100]
plt.figure(figsize=(10,15))
plt.barh(df_1["Description"],df_1["onHand"])
# Out:
# <BarContainer object of 75 artists>

# %% [markdown]
# ## The List Of Alcohol for which price was paid where Quantity was Greater than 100

# %%
df_1 = df_1.loc[df_1["onHand"]>100]
plt.figure(figsize=(10,15))
plt.barh(df_1["Description"],df_1["Total cost"])
# Out:
# <BarContainer object of 75 artists>

# %% [markdown]
# ## On An average price was paid 2000 usd ... Values Maxed somewhere between 4000 - 6000 usd

# %% [markdown]
# ## Analyzing the Quantity when Price paid was 4000-6000 usd

# %%
df_1 = df_1.loc[df_1["Total cost"]>4000]
plt.barh(df_1["Description"],df_1["onHand"])
# Out:
# <BarContainer object of 12 artists>

# %%
df_1
# Out:
#           InventoryId  Store      City  Brand                Description  \
# 3616  2_ASHBORNE_2589      2  ASHBORNE   2589      Jameson Irish Whiskey
# 4923  2_ASHBORNE_8680      2  ASHBORNE   8680                Crown Royal
# 3368  2_ASHBORNE_1233      2  ASHBORNE   1233    Jack Daniels No 7 Black
# 4776  2_ASHBORNE_8112      2  ASHBORNE   8112                Stolichnaya
# 4762  2_ASHBORNE_8068      2  ASHBORNE   8068           Absolut 80 Proof
# 4792  2_ASHBORNE_8159      2  ASHBORNE   8159       Jose Cuervo Especial
# 4176  2_ASHBORNE_4227      2  ASHBORNE   4227  Bacardi Superior Rum Trav
# 4069  2_ASHBORNE_3858      2  ASHBORNE   3858           Grey Goose Vodka
# 4074  2_ASHBORNE_3876      2  ASHBORNE   3876          Smirnoff 80 Proof
# 3397  2_ASHBORNE_1376      2  ASHBORNE   1376                   Jim Beam
# 4192  2_ASHBORNE_4261      2  ASHBORNE   4261     Capt Morgan Spiced Rum
# 3929  2_ASHBORNE_3545      2  ASHBORNE   3545            Ketel One Vodka
#
# ...

# %% [markdown]
# ## On an Average Quantity was 120-170 where Price for 1 Single was 30 - 40 usd

# %% [markdown]
# ## Analyzing the Data for EANVERNESS

# %% [markdown]
# ## On An average quantity was 100-150 ... Max was somewhere between 350-400

# %%
df_2 = df_2.loc[df_2["onHand"]>100]
plt.figure(figsize=(10,45))
plt.barh(df_2["Description"],df_2["onHand"])
# Out:
# <BarContainer object of 73 artists>

# %%
df_2 = df_2.loc[df_2["onHand"]>100]
plt.figure(figsize=(10,35))
plt.barh(df_2["Description"],df_2["Total cost"])
# Out:
# <BarContainer object of 73 artists>

# %% [markdown]
# ## In Eaverness Also average quantity price paid was 2000-4000 ... Max was Between 6000-8000

# %% [markdown]
# ## Analyzing the data where Price was greater then 6000 usd

# %%
df_2 = df_2.loc[df_2["Total cost"]>6000]
plt.barh(df_2["Description"],df_2["onHand"])
# Out:
# <BarContainer object of 2 artists>

# %%
df_2
# Out:
#             InventoryId  Store        City  Brand            Description  \
# 7154  4_EANVERNESS_3650      4  EANVERNESS   3650  Patron Silver Tequila
# 7116  4_EANVERNESS_3545      4  EANVERNESS   3545        Ketel One Vodka
#
#        Size  onHand  Price   startDate  Total cost
# 7154  750mL     126  48.99  2016-01-01     6172.74
# 7116  1.75L     243  31.99  2016-01-01     7773.57

# %% [markdown]
# ## Ketel One Vodka had Quantity of 250 which is insane
