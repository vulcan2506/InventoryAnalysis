# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("BegInvFINAL12312016.csv")
df1.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0        InventoryId  Store          City  Brand  \
# 0             0           0  1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1             1           1  1_HARDERSFIELD_60      1  HARDERSFIELD     60
# 2             2           2  1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 3             3           3  1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 4             4           4  1_HARDERSFIELD_72      1  HARDERSFIELD     72
#
#                    Description   Size  onHand  Price   startDate
# 0  Gekkeikan Black & Gold Sake  750mL     8.0  12.99  2016-01-01
# 1       Canadian Club 1858 VAP  750mL     7.0  10.99  2016-01-01
# 2     Herradura Silver Tequila  750mL     6.0  36.99  2016-01-01
# 3   Herradura Reposado Tequila  750mL     3.0  38.99  2016-01-01
# 4         No. 3 London Dry Gin  750mL     6.0  34.99  2016-01-01

# %%
df2 = pd.read_csv("InvoicePurchases12312016.csv")

# %%
df2.head()
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2016-01-09      8169
# 3           480  BACARDI USA INC              2016-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2016-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2015-12-21  2016-02-16         6     214.26     3.47     None
# 1  2015-12-22  2016-02-21        15     140.55     8.57     None
# 2  2015-12-24  2016-02-16         5     106.60     4.61     None
# 3  2015-12-20  2016-02-05     10100  137483.78  2935.20     None
# 4  2015-12-24  2016-02-12      1935   15527.25   429.20     None

# %%
plt.figure(figsize=(10,25))
plt.barh(df2["VendorName"],df2["Quantity"])
# Out:
# <BarContainer object of 5543 artists>

# %% [markdown]
# # Analyzing The data when quantity is greater than 30k

# %%
df2_ = df2.loc[df2["Quantity"]>30000]

# %%
df2_.head()
# Out:
#      VendorNumber                   VendorName InvoiceDate  PONumber  \
# 93            480  BACARDI USA INC              2016-01-19      8288
# 105          1392  CONSTELLATION BRANDS INC     2016-01-12      8252
# 109          3960  DIAGEO NORTH AMERICA INC     2016-01-14      8271
# 114          3252  E & J GALLO WINERY           2016-01-18      8238
# 126         12546  JIM BEAM BRANDS COMPANY      2016-01-16      8241
#
#          PODate     PayDate  Quantity    Dollars  Freight        Approval
# 93   2016-01-01  2016-02-18     32463  396606.13  1864.05  Frank Delahunt
# 105  2015-12-30  2016-02-11     36543  248369.62  1291.52            None
# 109  2015-12-31  2016-02-11    100183  954454.16  4581.38  Frank Delahunt
# 114  2015-12-29  2016-02-14     36991  238980.15  1194.90            None
# 126  2015-12-29  2016-02-15     56213  559691.95  2910.40  Frank Delahunt

# %% [markdown]
# ## A PO number or purchase order number is a unique number given to a particular order placed before the seller, similar to the invoice number. P.O. numbers are useful for administrative purposes in a business organisation.

# %% [markdown]
# ## The PO lists the order details and the delivery date of the order, while an invoice includes the price of the order, terms and conditions of payment, and the payment due date. A PO is generated when the customer places the order, while an invoice is generated after the order is complete.

# %%
plt.figure(figsize=(15,10))
plt.barh(df2_["VendorName"],df2_["Dollars"])
# Out:
# <BarContainer object of 318 artists>

# %%
plt.barh(df2_["VendorName"],df2_["Freight"])
# Out:
# <BarContainer object of 318 artists>

# %%
df2__ = df2_.loc[df2_["Approval"]!="None"]

# %%
df2__["Approval"].unique()
# Out:
# array(['Frank Delahunt'], dtype=object)

# %% [markdown]
# ## Approval was given to Frank Delahunt

# %%
df2__= df2__.sort_values("Dollars",ascending=False)
df2__.head()
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 4728          3960  DIAGEO NORTH AMERICA INC     2016-11-15     12833
# 4521          3960  DIAGEO NORTH AMERICA INC     2016-11-03     12618
# 4627          3960  DIAGEO NORTH AMERICA INC     2016-11-12     12771
# 2822          3960  DIAGEO NORTH AMERICA INC     2016-07-16     10936
# 3025          3960  DIAGEO NORTH AMERICA INC     2016-08-01     11191
#
#           PODate     PayDate  Quantity     Dollars  Freight        Approval
# 4728  2016-10-30  2016-12-19    141660  1660435.88  8468.22  Frank Delahunt
# 4521  2016-10-16  2016-12-14    122740  1468470.64  7048.66  Frank Delahunt
# 4627  2016-10-26  2016-12-24    127553  1409683.51  7753.26  Frank Delahunt
# 2822  2016-06-27  2016-08-13    131712  1377224.55  7574.74  Frank Delahunt
# 3025  2016-07-14  2016-09-07    128861  1354087.31  7041.25  Frank Delahunt

# %%
df2__.tail()
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 5245          3252  E & J GALLO WINERY           2016-12-24     13393
# 3539          3252  E & J GALLO WINERY           2016-09-03     11656
# 1825          3252  E & J GALLO WINERY           2016-05-12      9958
# 3321          1392  CONSTELLATION BRANDS INC     2016-08-22     11459
# 5142          3252  E & J GALLO WINERY           2016-12-15     13323
#
#           PODate     PayDate  Quantity    Dollars  Freight        Approval
# 5245  2016-12-07  2017-01-20     40760  256432.37  1333.45  Frank Delahunt
# 3539  2016-08-15  2016-10-15     37017  256077.20  1408.42  Frank Delahunt
# 1825  2016-04-26  2016-06-20     38524  253473.94  1343.41  Frank Delahunt
# 3321  2016-08-02  2016-09-15     38262  251777.71  1258.89  Frank Delahunt
# 5142  2016-12-02  2017-01-28     40378  251618.90  1232.93  Frank Delahunt

# %% [markdown]
# ## Aprooval Was only given When The Total Amount was greater than 2,50,000 to Frank Delhaunt

# %% [markdown]
# ## What does goods sent on approval mean?
# ## The goods sold on approval or return basis implies that the goods are sent to the buyer on a condition that if he likes the goods he can keep them else returns them.

# %%
plt.barh(df2__["VendorName"],df2__["Dollars"])
# Out:
# <BarContainer object of 274 artists>

# %%
plt.barh(df2__["VendorName"],df2__["Quantity"])
# Out:
# <BarContainer object of 274 artists>

# %% [markdown]
# ## Diageo plc is a British multinational alcoholic beverage company, with its headquarters in London, England. It operates from 132 sites around the world. It is a major distributor of Scotch whisky and other spirits.

# %% [markdown]
# ## Diageo Had the Higest Quantity out of all and Price as well to be Paid
# ## Whereas Brown Foman Had the lowest Quantity And Price to be paid

# %%
plt.barh(df2__["VendorName"],df2__["Freight"])
# Out:
# <BarContainer object of 274 artists>

# %% [markdown]
# ## The Lowest Fright Paid was apx 2000 and Highest was more than 8000 in the case of Diageo North America

# %% [markdown]
# ## When Order Quantity is above 30k and Aprooval is given to none

# %%
df2___ = df2_.loc[df2_["Approval"]=="None"]
df2___ = df2___.sort_values("Dollars",ascending=False)

# %%
df2___.head()
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 4934          3252  E & J GALLO WINERY           2016-11-28     13127
# 2148          9552  M S WALKER INC               2016-06-05     10229
# 105           1392  CONSTELLATION BRANDS INC     2016-01-12      8252
# 910           1392  CONSTELLATION BRANDS INC     2016-03-13      9065
# 5264          9552  M S WALKER INC               2016-12-23     13395
#
#           PODate     PayDate  Quantity    Dollars  Freight Approval
# 4934  2016-11-18  2017-01-08     37969  249821.96  1149.18     None
# 2148  2016-05-15  2016-07-08     33293  249142.22  1195.88     None
# 105   2015-12-30  2016-02-11     36543  248369.62  1291.52     None
# 910   2016-02-24  2016-04-13     36477  246611.41  1233.06     None
# 5264  2016-12-07  2017-01-24     30528  246201.54  1354.11     None

# %%
plt.barh(df2___["VendorName"],df2___["Dollars"])
# Out:
# <BarContainer object of 44 artists>

# %%
plt.barh(df2___["VendorName"],df2___["Quantity"])
# Out:
# <BarContainer object of 44 artists>

# %%
plt.barh(df2___["VendorName"],df2___["Freight"])
# Out:
# <BarContainer object of 44 artists>

# %%
df3 = pd.read_csv("PurchasesFINAL12312016.csv")

# %%
df3.shape
# Out:
# (2372474, 16)

# %%
df4 = pd.read_csv("SalesFINAL12312016.csv")
df5 = pd.read_csv("EndInvFINAL12312016.csv")
df6 = pd.read_csv("2017PurchasePricesDec.csv")

df4.head()
# Out:
#            InventoryId  Store  Brand                 Description        Size  \
# 0  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 1  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 2  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 3  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 4  1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack  375mL 2 Pk
#
#    SalesQuantity  SalesDollars  SalesPrice SalesDate  Volume  Classification  \
# 0              1         16.49       16.49  1/1/2016     750               1
# 1              2         32.98       16.49  1/2/2016     750               1
# 2              1         16.49       16.49  1/3/2016     750               1
# 3              1         14.49       14.49  1/8/2016     750               1
# 4              2         69.98       34.99  1/9/2016     375               1
#
# ...

# %%
df4.shape
# Out:
# (1048575, 14)

# %%
df5.head()
# Out:
#    Unnamed: 0        InventoryId  Store          City  Brand  \
# 0           0  1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1           1  1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 2           2  1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 3           3  1_HARDERSFIELD_72      1  HARDERSFIELD     72
# 4           4  1_HARDERSFIELD_75      1  HARDERSFIELD     75
#
#                    Description   Size  onHand  Price     endDate
# 0  Gekkeikan Black & Gold Sake  750mL      11  12.99  2016-12-31
# 1     Herradura Silver Tequila  750mL       7  36.99  2016-12-31
# 2   Herradura Reposado Tequila  750mL       7  38.99  2016-12-31
# 3         No. 3 London Dry Gin  750mL       4  34.99  2016-12-31
# 4    Three Olives Tomato Vodka  750mL       7  14.99  2016-12-31

# %% [markdown]
# ## 2017 Purchase Price

# %%
df6.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Brand                  Description  \
# 0             0             0           0     58  Gekkeikan Black & Gold Sake
# 1             1             1           1     62     Herradura Silver Tequila
# 2             2             2           2     63   Herradura Reposado Tequila
# 3             3             3           3     72         No. 3 London Dry Gin
# 4             4             4           4     75    Three Olives Tomato Vodka
#
#    Price   Size Volume  Classification  PurchasePrice  VendorNumber  \
# 0  12.99  750mL    750               1           9.28          8320
# 1  36.99  750mL    750               1          28.67          1128
# 2  38.99  750mL    750               1          30.46          1128
# 3  34.99  750mL    750               1          26.11          9165
# 4  14.99  750mL    750               1          10.94          7245
#
#                     VendorName
# 0  SHAW ROSS INT L IMP LTD
# 1  BROWN-FORMAN CORP
# ...

# %%
df6.dtypes
# Out:
# Unnamed: 0.2        int64
# Unnamed: 0.1        int64
# Unnamed: 0          int64
# Brand               int64
# Description        object
# Price             float64
# Size               object
# Volume             object
# Classification      int64
# PurchasePrice     float64
# VendorNumber        int64
# VendorName         object
# dtype: object

# %%
df6 = df6.fillna(0)

# %%
df6.isnull().sum()
# Out:
# Unnamed: 0.2      0
# Unnamed: 0.1      0
# Unnamed: 0        0
# Brand             0
# Description       0
# Price             0
# Size              0
# Volume            0
# Classification    0
# PurchasePrice     0
# VendorNumber      0
# VendorName        0
# dtype: int64

# %%
df6["Volume"].unique()
# Out:
# array(['750', '1000', '1750', '50', '375', '100', '200', '300', 'Unknown',
#        '250', '1500', '3000', '5000', '4000', '187', '150', '500', '720',
#        '650', '330', '18000', '180', '6000', '20', 0, '20000', '162.5',
#        '400', '1100', '600', '19500', '560', '3750', '9000'], dtype=object)

# %%
df6 = df6.loc[df6["Volume"]!="Unknown"]
df6["Volume"] = df6["Volume"].astype(float)

# %%
df6["Volume"] = np.abs(df6["Volume"])

# %%
df6["Volume"] = df6["Volume"].astype(int)

# %%
df6 = df6.sort_values("Volume",ascending=True)

# %%
df6.head()
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Brand  \
# 7915          7915          7915        7915   4202
# 7858          7858          7858        7858   9110
# 227            227           227         227   1867
# 8324          8324          8324        8324   4379
# 8319          8319          8319        8319   4042
#
#                        Description  Price       Size  Volume  Classification  \
# 7915                             0   0.00          0       0               1
# 7858  The Bitter Truth 5/20mls Pak  16.99  20mL 5 Pk      20               1
# 227   Jack Daniels Tennessee Honey   2.99       50mL      50               1
# 8324               Bacardi Coconut   0.99       50mL      50               1
# 8319          Bacardi Dragon Berry   0.99       50mL      50               1
#
#       PurchasePrice  VendorNumber                   VendorName
# 7915          11.19           480  BACARDI USA INC
# 7858          12.22          4425        MARTIGNETTI COMPANIES
# ...

# %%
df6.tail()
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Brand            Description  \
# 10508         10508         10508       10508  23491    True Myth Chard Keg
# 11400         11400         11400       11400  25464    Eden Rose Cider Keg
# 12018         12018         12018       12018  26146   Montelvini CabMerlot
# 9406           9406          9406        9406  25463     Eden Dry Cider Keg
# 8798           8798          8798        8798  23047  From the Tank Red Keg
#
#        Price     Size  Volume  Classification  PurchasePrice  VendorNumber  \
# 10508  58.49  20000mL   20000               2          39.99         90047
# 11400  58.49  20000mL   20000               2          39.99         90047
# 12018  58.49  20000mL   20000               2          39.99         90011
# 9406   58.49  20000mL   20000               2          39.99         90047
# 8798   58.49  20000mL   20000               2          39.99         90024
#
#                         VendorName
# 10508  CRUSH WINES
# ...

# %%
df6.skew()
# Out:
# /tmp/ipykernel_13867/3877000375.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df6.skew()
# Unnamed: 0.2       0.000231
# Unnamed: 0.1       0.000231
# Unnamed: 0         0.000231
# Brand              0.644602
# Price              1.093557
# Volume            16.344099
# Classification    -0.921143
# PurchasePrice      1.102123
# VendorNumber       4.011471
# dtype: float64

# %%
df6["Size"] = df6["Size"].astype(str)
df6["Volume"] = df6["Volume"].astype(str)
df6["Volume"].unique()
# Out:
# array(['0', '20', '50', '100', '150', '162', '180', '187', '200', '250',
#        '300', '330', '375', '400', '500', '560', '600', '650', '720',
#        '750', '1000', '1100', '1500', '1750', '3000', '3750', '4000',
#        '5000', '6000', '9000', '18000', '19500', '20000'], dtype=object)

# %%
plt.figure(figsize=(10,20))
plt.barh(df6["Volume"],df6["Price"])
# Out:
# <BarContainer object of 12257 artists>

# %%
plt.figure(figsize=(10,20))
plt.barh(df6["Volume"],df6["PurchasePrice"])
# Out:
# <BarContainer object of 12257 artists>

# %%
df6_ = df6.loc[df6["Volume"]=="200"]

# %%
df6_.head()
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Brand  \
# 10073         10073         10073       10073    365
# 4075           4075          4075        4075   6129
# 10760         10760         10760       10760    156
# 10762         10762         10762       10762    275
# 4074           4074          4074        4074   6120
#
#                         Description  Price   Size Volume  Classification  \
# 10073                   Ciroc Vodka   7.99  200mL    200               1
# 4075              The Club Mudslide   1.99  200mL    200               1
# 10760  The Bitter Truth Cucumber Bi  19.99  200mL    200               1
# 10762     The Bitter Truth Aromatic  19.99  200mL    200               1
# 4074           The Club Pina Colada   1.99  200mL    200               1
#
#        PurchasePrice  VendorNumber                   VendorName
# 10073           6.15          3960  DIAGEO NORTH AMERICA INC
# 4075            1.45          3960  DIAGEO NORTH AMERICA INC
# ...

# %%
plt.figure(figsize=(10,20))
plt.barh(df6_["Description"],df6_["PurchasePrice"])
# Out:
# <BarContainer object of 34 artists>

# %% [markdown]
# ## These Were the wines that were sold for 40 usd For 200ML

# %%
d = df6_.loc[df6_["PurchasePrice"]>=35.00]
d
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Brand  \
# 11805         11805         11805       11805   1072
# 398             398           398         398   2604
# 10227         10227         10227       10227   1498
#
#                         Description  Price        Size Volume  Classification  \
# 11805  Bruichladdich Wee Laddie Box  58.49  200mL 3 Pk    200               1
# 398     Johnnie Walker Collection 4  58.49  200mL 4 Pk    200               1
# 10227   Jefferson's Wood Experiment  58.49  200mL 5 Pk    200               1
#
#        PurchasePrice  VendorNumber                   VendorName
# 11805          39.99          7239  REMY COINTREAU USA INC
# 398            39.99          3960  DIAGEO NORTH AMERICA INC
# 10227          39.99          1485  CASTLE BRANDS CORP.

# %% [markdown]
# ## Analyzing The Wines Above 6000ml which were sold for 40 usd

# %%
df6["Volume"] = df6["Volume"].astype(int)

# %%
df_6 = df6.loc[df6["Volume"]>=6000]

# %%
df_6
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Brand  \
# 8682           8682          8682        8682  11668
# 11441         11441         11441       11441  25765
# 10442         10442         10442       10442  25770
# 6061           6061          6061        6061  16191
# 12012         12012         12012       12012  25457
# 8564           8564          8564        8564  24144
# 4206           4206          4206        4206  20650
# 5633           5633          5633        5633  29427
# 11260         11260         11260       11260  22565
# 10508         10508         10508       10508  23491
# 11400         11400         11400       11400  25464
# 12018         12018         12018       12018  26146
# 9406           9406          9406        9406  25463
# 8798           8798          8798        8798  23047
#
#                         Description  Price     Size  Volume  Classification  \
# 8682      Taittinger Brut Francaise  58.49   6000mL    6000               2
# ...

# %% [markdown]
# ## These Were The Wines Which Were Sold For for 40 usd for more than 6L to 20L

# %%
df_6 = df6.loc[df6["Description"]=="Johnnie Walker Collection 4"]

# %%
df_6
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Brand  \
# 398           398           398         398   2604
#
#                      Description  Price        Size  Volume  Classification  \
# 398  Johnnie Walker Collection 4  58.49  200mL 4 Pk     200               1
#
#      PurchasePrice  VendorNumber                   VendorName
# 398          39.99          3960  DIAGEO NORTH AMERICA INC

# %% [markdown]
# ## We Can consider that the wines which were sold for 40 usd for 6l - 20l were a Cheap quality brand. Whereas Quality brands like Johnnie Walker Collection 4 at 200ml Costs 40 usd. For 20l It would have costed 4000 usd which is purely expensive

# %% [markdown]
# ## Seeing those Wines which were sold for 40 usd in 200ml Quantity

# %%
d
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Brand  \
# 11805         11805         11805       11805   1072
# 398             398           398         398   2604
# 10227         10227         10227       10227   1498
#
#                         Description  Price        Size Volume  Classification  \
# 11805  Bruichladdich Wee Laddie Box  58.49  200mL 3 Pk    200               1
# 398     Johnnie Walker Collection 4  58.49  200mL 4 Pk    200               1
# 10227   Jefferson's Wood Experiment  58.49  200mL 5 Pk    200               1
#
#        PurchasePrice  VendorNumber                   VendorName
# 11805          39.99          7239  REMY COINTREAU USA INC
# 398            39.99          3960  DIAGEO NORTH AMERICA INC
# 10227          39.99          1485  CASTLE BRANDS CORP.

# %%
df6["Classification"].unique()
# Out:
# array([1, 2])

# %%
plt.barh(d["Description"],d["PurchasePrice"])
# Out:
# <BarContainer object of 3 artists>

# %%
df1 = pd.read_csv("BegInvFINAL12312016.csv")
df1.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0        InventoryId  Store          City  Brand  \
# 0             0           0  1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1             1           1  1_HARDERSFIELD_60      1  HARDERSFIELD     60
# 2             2           2  1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 3             3           3  1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 4             4           4  1_HARDERSFIELD_72      1  HARDERSFIELD     72
#
#                    Description   Size  onHand  Price   startDate
# 0  Gekkeikan Black & Gold Sake  750mL     8.0  12.99  2016-01-01
# 1       Canadian Club 1858 VAP  750mL     7.0  10.99  2016-01-01
# 2     Herradura Silver Tequila  750mL     6.0  36.99  2016-01-01
# 3   Herradura Reposado Tequila  750mL     3.0  38.99  2016-01-01
# 4         No. 3 London Dry Gin  750mL     6.0  34.99  2016-01-01

# %%
df1 = df1[:10000]

# %%
df1.skew()
# Out:
# /tmp/ipykernel_13867/149261804.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.skew()
# Unnamed: 0.1    0.000000
# Unnamed: 0      0.000000
# Store           0.343319
# Brand           1.304821
# onHand          1.146997
# Price           0.825880
# dtype: float64

# %%
plt.boxplot(df1["onHand"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f65772eecd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f65772f81d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6597bf4a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f65772f9410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f65772f9cd0>],
#  'means': []}

# %%
df1.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0        Store        Brand        onHand  \
# count   10000.00000  10000.00000  10000.00000  10000.00000  10000.000000
# mean     4999.50000   4999.50000      2.50800  12105.13390     14.313200
# std      2886.89568   2886.89568      1.37758  12388.51967     11.926782
# min         0.00000      0.00000      1.00000     58.00000      0.000000
# 25%      2499.75000   2499.75000      1.00000   3485.00000      6.000000
# 50%      4999.50000   4999.50000      2.00000   5952.00000     11.000000
# 75%      7499.25000   7499.25000      4.00000  18370.50000     19.000000
# max      9999.00000   9999.00000      5.00000  47090.00000     42.000000
#
#               Price
# count  10000.000000
# mean      17.795466
# std       10.647335
# min        0.990000
# 25%        9.990000
# 50%       14.990000
# 75%       22.990000
# max       39.990000

# %%
df1.dtypes
# Out:
# Unnamed: 0.1      int64
# Unnamed: 0        int64
# InventoryId      object
# Store             int64
# City             object
# Brand             int64
# Description      object
# Size             object
# onHand          float64
# Price           float64
# startDate        object
# dtype: object

# %%
df1.shape
# Out:
# (10000, 11)

# %%
plt.figure(figsize=(5,35))
plt.barh(df1["Description"],df1["onHand"])
# Out:
# <BarContainer object of 10000 artists>
