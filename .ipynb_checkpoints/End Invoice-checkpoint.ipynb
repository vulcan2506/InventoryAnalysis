# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("EndInvFINAL12312016.csv")

# %%
df = df[:10000]

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.tail()
# Out:
#       Unnamed: 0    InventoryId  Store    City  Brand  \
# 9995        9995  5_SUTTON_6590      5  SUTTON   6590
# 9996        9996  5_SUTTON_6593      5  SUTTON   6593
# 9997        9997  5_SUTTON_6595      5  SUTTON   6595
# 9998        9998  5_SUTTON_6596      5  SUTTON   6596
# 9999        9999  5_SUTTON_6599      5  SUTTON   6599
#
#                        Description   Size  onHand  Price     endDate
# 9995      Almaden B/B Wh Znfdl Cal     5L       8  14.99  2016-12-31
# 9996         Souverain Chard N Cst  750mL      12   9.99  2016-12-31
# 9997                  Bogle Merlot  750mL      34   7.99  2016-12-31
# 9998        Kenwood Svgn Bl Sonoma  750mL       6  10.99  2016-12-31
# 9999  Estancia Cab Svgn Paso Roble  750mL       8  12.99  2016-12-31

# %%
 df["Total cost"] = np.multiply(df["onHand"],df["Price"])

# %%
df
# Out:
#       Unnamed: 0        InventoryId  Store          City  Brand  \
# 0              0  1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1              1  1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 2              2  1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 3              3  1_HARDERSFIELD_72      1  HARDERSFIELD     72
# 4              4  1_HARDERSFIELD_75      1  HARDERSFIELD     75
# ...          ...                ...    ...           ...    ...
# 9995        9995      5_SUTTON_6590      5        SUTTON   6590
# 9996        9996      5_SUTTON_6593      5        SUTTON   6593
# 9997        9997      5_SUTTON_6595      5        SUTTON   6595
# 9998        9998      5_SUTTON_6596      5        SUTTON   6596
# 9999        9999      5_SUTTON_6599      5        SUTTON   6599
#
#                        Description   Size  onHand  Price     endDate  \
# 0      Gekkeikan Black & Gold Sake  750mL      11  12.99  2016-12-31
# 1         Herradura Silver Tequila  750mL       7  36.99  2016-12-31
# 2       Herradura Reposado Tequila  750mL       7  38.99  2016-12-31
# 3             No. 3 London Dry Gin  750mL       4  34.99  2016-12-31
# 4        Three Olives Tomato Vodka  750mL       7  14.99  2016-12-31
# ...                            ...    ...     ...    ...         ...
# 9995      Almaden B/B Wh Znfdl Cal     5L       8  14.99  2016-12-31
# 9996         Souverain Chard N Cst  750mL      12   9.99  2016-12-31
# 9997                  Bogle Merlot  750mL      34   7.99  2016-12-31
# 9998        Kenwood Svgn Bl Sonoma  750mL       6  10.99  2016-12-31
# 9999  Estancia Cab Svgn Paso Roble  750mL       8  12.99  2016-12-31
#
#       Total cost
# 0         142.89
# 1         258.93
# 2         272.93
# 3         139.96
# 4         104.93
# ...          ...
# 9995      119.92
# 9996      119.88
# 9997      271.66
# 9998       65.94
# 9999      103.92
#
# [10000 rows x 11 columns]

# %%
df["onHand"].unique()
# Out:
# array([ 11,   7,   4,  18,  35,  36,   8,  24,  10,   6,   5,   3,  46,
#         96,   2,   0,  21,  40,  16,   1,  29,  23,   9,  39,  57,  22,
#         20,  12,  14,  19,  13,  28,  17,  15,  60,  31,  26,  30,  27,
#         32,  37, 177,  70,  48, 145,  53, 245,  47,  54, 179,  33,  38,
#        109,  78,  56,  67,  68,  34,  80, 157, 496,  43,  62, 103, 132,
#         71,  74, 187, 104, 120,  58,  59,  66,  77,  25,  72, 151,  79,
#        154, 195,  44,  50,  49,  65, 391, 127,  52,  42, 159,  45, 255,
#        233, 146,  51, 178,  93, 210, 102, 243, 214, 220, 100, 225, 378,
#         75, 166, 111,  61,  85,  83, 112,  55,  41, 169, 201,  69,  94,
#         73, 356, 188, 305, 136, 141, 147,  63, 107, 163, 106, 137, 200,
#        156, 126,  97,  84, 121, 238, 143, 189,  64,  89, 199, 304, 124,
#        116,  90, 113, 320, 182, 119, 184, 139, 417, 142, 155, 115, 133,
#        138, 149, 108, 338, 259, 249, 110, 101,  98, 186,  82, 117, 125,
#        251,  81,  87, 161,  91, 131,  92,  99,  88, 129, 148,  76, 289,
#        135, 205, 173, 207, 118, 250, 174, 211, 240, 279, 218, 262, 197,
#        162, 292,  95, 153, 196, 221, 171, 134, 172, 176, 208, 213, 202,
#         86, 150, 160, 128, 168, 164, 193, 122, 194, 123, 105, 400, 181,
#        198, 180, 167, 185, 114, 252, 325, 230])

# %%
df = df.sort_values("onHand",ascending=True)

# %%
df.skew()
# Out:
# /tmp/ipykernel_4980/1665899112.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# Unnamed: 0    0.000000
# Store         0.336026
# Brand         1.349892
# onHand        4.455351
# Price         0.889237
# Total cost    7.506632
# dtype: float64

# %%
plt.boxplot(df["Price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7afb812810>,
#   <matplotlib.lines.Line2D at 0x7f7afb8131d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f7afb813b90>,
#   <matplotlib.lines.Line2D at 0x7f7afb8204d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7afcb1af50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7afb802b90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7afb8213d0>],
#  'means': []}

# %%
df.describe()
# Out:
#         Unnamed: 0         Store        Brand        onHand         Price  \
# count  10000.00000  10000.000000  10000.00000  10000.000000  10000.000000
# mean    4999.50000      2.529800  11801.64700     21.760700     18.527790
# std     2886.89568      1.386688  12171.34739     31.525289     11.652717
# min        0.00000      1.000000     58.00000      0.000000      0.990000
# 25%     2499.75000      1.000000   3397.00000      7.000000      9.990000
# 50%     4999.50000      2.000000   5830.50000     12.000000     14.990000
# 75%     7499.25000      4.000000  18027.00000     22.000000     24.990000
# max     9999.00000      5.000000  90631.00000    496.000000     43.740000
#
#          Total cost
# count  10000.000000
# mean     301.886876
# std      459.100065
# min        0.000000
# 25%      107.940000
# 50%      186.385000
# 75%      318.710000
# max    11996.000000

# %%
plt.figure(figsize=(10,25))
plt.barh(df["Description"],df["onHand"])
# Out:
# <BarContainer object of 10000 artists>

# %%
df1 = df.loc[df["onHand"]>100]
df1.shape
# Out:
# (338, 11)

# %%
plt.figure(figsize=(10,45))
plt.barh(df1["Description"],df1["onHand"])
# Out:
# <BarContainer object of 338 artists>

# %%
plt.barh(df["City"],df["onHand"])
# Out:
# <BarContainer object of 10000 artists>

# %%
df_1 = df.loc[df["City"]=="HARDERSFIELD"]
df_2 = df.loc[df["City"]=="EANVERNESS"]

# %%
df_1.shape
# Out:
# (3192, 11)

# %%
df_2.shape
# Out:
# (2851, 11)

# %% [markdown]
# ## Analysis On Alcohol Purchased from Ashborne Where quantity was greater than 100

# %%
df_1 = df_1.loc[df_1["onHand"]>100]
plt.figure(figsize=(10,45))
plt.barh(df_1["Description"],df_1["onHand"])
# Out:
# <BarContainer object of 129 artists>

# %% [markdown]
# ## The List Of Alcohol for which price was paid where Quantity was Greater than 100

# %%
df_1 = df_1.loc[df_1["onHand"]>100]
plt.figure(figsize=(10,35))
plt.barh(df_1["Description"],df_1["Total cost"])
# Out:
# <BarContainer object of 129 artists>

# %% [markdown]
# ## On An average price was paid 2000 usd ... Values Maxed somewhere between 4000 - 6000 usd

# %% [markdown]
# ## Analyzing the Quantity when Price paid was 4000-6000 usd

# %%
df_1 = df_1.loc[df_1["Total cost"]>4000]
plt.barh(df_1["Description"],df_1["onHand"])
# Out:
# <BarContainer object of 9 artists>

# %%
df_1
# Out:
#       Unnamed: 0          InventoryId  Store          City  Brand  \
# 838          838  1_HARDERSFIELD_3650      1  HARDERSFIELD   3650
# 1528        1528  1_HARDERSFIELD_6654      1  HARDERSFIELD   6654
# 179          179  1_HARDERSFIELD_1346      1  HARDERSFIELD   1346
# 537          537  1_HARDERSFIELD_2757      1  HARDERSFIELD   2757
# 1688        1688  1_HARDERSFIELD_8159      1  HARDERSFIELD   8159
# 742          742  1_HARDERSFIELD_3405      1  HARDERSFIELD   3405
# 156          156  1_HARDERSFIELD_1233      1  HARDERSFIELD   1233
# 795          795  1_HARDERSFIELD_3545      1  HARDERSFIELD   3545
# 1658        1658  1_HARDERSFIELD_8068      1  HARDERSFIELD   8068
#
#                      Description   Size  onHand  Price     endDate  Total cost
# 838        Patron Silver Tequila  750mL     111  43.74  2016-12-31     4855.14
# 1528  Veuve Clicquot Brut Yellow  750mL     124  39.99  2016-12-31     4958.76
# 179           Knob Creek Bourbon  750mL     145  30.99  2016-12-31     4493.55
# 537     Johnnie Walker Red Label  1.75L     151  28.99  2016-12-31     4377.49
# 1688        Jose Cuervo Especial  1.75L     155  26.99  2016-12-31     4183.45
# 742        Tito's Handmade Vodka  1.75L     159  28.99  2016-12-31     4609.41
# 156      Jack Daniels No 7 Black  1.75L     177  34.99  2016-12-31     6193.23
# 795              Ketel One Vodka  1.75L     178  29.99  2016-12-31     5338.22
# 1658            Absolut 80 Proof  1.75L     184  23.49  2016-12-31     4322.16

# %% [markdown]
# ## On an Average Quantity was 120-170 where Price for 1 Single was 30 - 40 usd

# %% [markdown]
# ## Analyzing the Data for EANVERNESS

# %% [markdown]
# ## On An average quantity was 100-150 ... Max was somewhere between 350-400

# %%
df_2 = df_2.loc[df_2["onHand"]>100]
plt.figure(figsize=(10,45))
plt.barh(df_2["Description"],df_2["onHand"])
# Out:
# <BarContainer object of 94 artists>

# %%
df_2 = df_2.loc[df_2["onHand"]>100]
plt.figure(figsize=(10,35))
plt.barh(df_2["Description"],df_2["Total cost"])
# Out:
# <BarContainer object of 94 artists>

# %% [markdown]
# ## In Eaverness Also average quantity price paid was 2000-4000 ... Max was Between 6000-8000

# %% [markdown]
# ## Analyzing the data where Price was greater then 6000 usd

# %%
df_2 = df_2.loc[df_2["Total cost"]>6000]
plt.barh(df_2["Description"],df_2["onHand"])
# Out:
# <BarContainer object of 3 artists>

# %%
df_2
# Out:
#       Unnamed: 0        InventoryId  Store        City  Brand  \
# 7140        7140  4_EANVERNESS_3650      4  EANVERNESS   3650
# 6501        6501  4_EANVERNESS_1233      4  EANVERNESS   1233
# 7098        7098  4_EANVERNESS_3545      4  EANVERNESS   3545
#
#                   Description   Size  onHand  Price     endDate  Total cost
# 7140    Patron Silver Tequila  750mL     180  43.74  2016-12-31     7873.20
# 6501  Jack Daniels No 7 Black  1.75L     194  34.99  2016-12-31     6788.06
# 7098          Ketel One Vodka  1.75L     400  29.99  2016-12-31    11996.00

# %% [markdown]
# ## Ketel One Vodka had Quantity of 400 which is insane
